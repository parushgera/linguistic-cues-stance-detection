# %%
import pandas as pd
import numpy as np

# %%
file = 'feature_value_relationships_AGAINST_Logistic_Regression.csv'

# %%
df = pd.read_csv(file)
df.head(5)
# Out:
#             feature  mean_feat_when_shap_positive  \
# 0        word_count                      0.057976
# 1    sentence_count                     -0.509917
# 2   avg_word_length                      0.215374
# 3   std_word_length                      0.140863
# 4  type_token_ratio                      0.560526
#
#    std_feat_when_shap_positive  count_shap_positive  \
# 0                     0.982744                  671
# 1                     0.685553                  702
# 2                     0.951862                  668
# 3                     0.874804                  692
# 4                     0.695549                  681
#
#    mean_feat_when_shap_negative  std_feat_when_shap_negative  \
# 0                     -0.029119                     0.963543
# 1                      0.530578                     1.057697
# 2                      0.104998                     0.929362
# 3                      0.126510                     1.041733
# ...

# %%
df.columns
# Out:
# Index(['feature', 'mean_feat_when_shap_positive',
#        'std_feat_when_shap_positive', 'count_shap_positive',
#        'mean_feat_when_shap_negative', 'std_feat_when_shap_negative',
#        'count_shap_negative', 'overall_mean_feat', 'overall_std_feat',
#        'feature_shap_correlation', 'total_observations'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['feature', 'mean_feat_when_shap_positive',
#        'std_feat_when_shap_positive', 'count_shap_positive',
#        'mean_feat_when_shap_negative', 'std_feat_when_shap_negative',
#        'count_shap_negative', 'overall_mean_feat', 'overall_std_feat',
#        'feature_shap_correlation', 'total_observations'],
#       dtype='object')

# %%
df = df[['feature', 'mean_feat_when_shap_positive',
       'mean_feat_when_shap_negative']]
