# %%
import pandas as pd
import numpy as np

# %%
stance = 'FAVOR'
file = f"quartile_features_{stance}.csv"

# %%
df = pd.read_csv(file)

# %%
df = df[['feature', 'quartile', 'positive_ratio',
       'negative_ratio', 'mean_feat_when_shap_positive',
       'mean_feat_when_shap_negative']]
#df = df[df['quartile']=='Q1']

# %%
df.sort_values(by='positive_ratio')
# Out:
#                        feature quartile  positive_ratio  negative_ratio  \
# 41                     I_ratio       Q4        0.002322        0.466718
# 42               hedge_I_count       Q4        0.002322        0.466718
# 22                         joy       Q3        0.301084        0.698916
# 27               hedge_D_count       Q3        0.332043        0.667957
# 23               hedge_E_count       Q3        0.334365        0.665635
# 14          sentiment_polarity       Q3        0.339009        0.660991
# 33  certainty_adjectives_count       Q4        0.413313        0.586687
# 11                        fear       Q2        0.465170        0.534830
# 35   sentence_length_variation       Q4        0.472136        0.527864
# 21    subordinate_clause_ratio       Q4        0.477554        0.522446
# 16             std_word_length       Q3        0.478328        0.521672
# 24           punctuation_usage       Q3        0.478328        0.521672
# ...
