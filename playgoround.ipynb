# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('all_feature_significance_summary.csv')

# %%
df
# Out:
#                feature  dataset           target   stance  source  t_pvalue  \
# 0           word_count    whole              ALL  AGAINST   whole    0.0100
# 1       sentence_count    whole              ALL  AGAINST   whole    0.2578
# 2      avg_word_length    whole              ALL  AGAINST   whole    0.2192
# 3      std_word_length    whole              ALL  AGAINST   whole    0.1601
# 4     type_token_ratio    whole              ALL  AGAINST   whole    0.6392
# ...                ...      ...              ...      ...     ...       ...
# 1579           C_ratio  semeval  Hillary Clinton     NONE  target    0.5317
# 1580           D_ratio  semeval  Hillary Clinton     NONE  target       NaN
# 1581           E_ratio  semeval  Hillary Clinton     NONE  target    0.8547
# 1582           I_ratio  semeval  Hillary Clinton     NONE  target       NaN
# 1583           N_ratio  semeval  Hillary Clinton     NONE  target    0.4981
#
# ...

# %%
df_sig_only = df[df['significant']=='yes']
df_sig_only
# Out:
#                          feature  dataset           target   stance  source  \
# 0                     word_count    whole              ALL  AGAINST   whole
# 7            punctuation_density    whole              ALL  AGAINST   whole
# 18      subordinate_clause_ratio    whole              ALL  AGAINST   whole
# 19            sentiment_polarity    whole              ALL  AGAINST   whole
# 21                         anger    whole              ALL  AGAINST   whole
# ...                          ...      ...              ...      ...     ...
# 1562                         joy  semeval  Hillary Clinton     NONE  target
# 1563                        fear  semeval  Hillary Clinton     NONE  target
# 1564                     sadness  semeval  Hillary Clinton     NONE  target
# 1569  certainty_adjectives_count  semeval  Hillary Clinton     NONE  target
# 1570         doubt_adverbs_count  semeval  Hillary Clinton     NONE  target
#
# ...

# %%
df_new = pd.read_csv('all_feature_significanse_only.csv')
df_new
# Out:
#                         feature  dataset           target   stance  source  \
# 0                    word_count    whole              ALL  AGAINST   whole
# 1           punctuation_density    whole              ALL  AGAINST   whole
# 2      subordinate_clause_ratio    whole              ALL  AGAINST   whole
# 3            sentiment_polarity    whole              ALL  AGAINST   whole
# 4                         anger    whole              ALL  AGAINST   whole
# ..                          ...      ...              ...      ...     ...
# 331                         joy  semeval  Hillary Clinton     NONE  target
# 332                        fear  semeval  Hillary Clinton     NONE  target
# 333                     sadness  semeval  Hillary Clinton     NONE  target
# 334  certainty_adjectives_count  semeval  Hillary Clinton     NONE  target
# 335         doubt_adverbs_count  semeval  Hillary Clinton     NONE  target
#
# ...
