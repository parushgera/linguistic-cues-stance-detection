# %%
import json
import tweepy
import numpy as np

# assign the values accordingly
consumer_key = "yoWGkwpsEx4R31q6SfngK6yCB"
consumer_secret = "4PtkADZ4FjqDdQbgWIP6qnEIO6T24ss9N0qsHmvyvttBCDbg93"
access_token = "1320944197805973504-GGbpnnAblUhtOCz4n90C3gsfQehhFY"
access_token_secret = "GEjAMicOgoVxEqxZ20NFmkJ5frXMFCih2oToA6L5A5wEv"


# authorization of consumer key and consumer secret
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
  
# set access to user's access key and access secret 
auth.set_access_token(access_token, access_token_secret)
  
# calling the api 
api = tweepy.API(auth, wait_on_rate_limit = True)



wtwt = []
invalid = []
f = open('wtwt_ids.json',)
data = json.load(f)
i = 0
l = len(data)
for line in data:
    i += 1
    print('Extracting {} of {}'.format(i, l))
    tid = line['tweet_id']
    try:
        status = api.get_status(tid)
        tweet = status._json
        text = tweet['text']
        line['tweet'] = text
        wtwt.append(line)
    except Exception as e:
        print(e)
        invalid.append(tid)
# Out:
# Extracting 1 of 51284
# Extracting 2 of 51284
# Extracting 3 of 51284
# Extracting 4 of 51284
# Extracting 5 of 51284
# Extracting 6 of 51284
# Extracting 7 of 51284
# Extracting 8 of 51284
# Extracting 9 of 51284
# Extracting 10 of 51284
# Extracting 11 of 51284
# Extracting 12 of 51284
# Extracting 13 of 51284
# Extracting 14 of 51284
# Extracting 15 of 51284
# Extracting 16 of 51284
# Extracting 17 of 51284
# Extracting 18 of 51284
# 404 Not Found
# 144 - No status found with that ID.
# Extracting 19 of 51284
# Extracting 20 of 51284
# Extracting 21 of 51284
# Extracting 22 of 51284
# Extracting 23 of 51284
# Extracting 24 of 51284
# Extracting 25 of 51284
# Extracting 26 of 51284
# Extracting 27 of 51284
# Extracting 28 of 51284
# 404 Not Found
# 144 - No status found with that ID.
# Extracting 29 of 51284
# Extracting 30 of 51284
# Extracting 31 of 51284
# Extracting 32 of 51284
# Extracting 33 of 51284
# Extracting 34 of 51284
# Extracting 35 of 51284
# Extracting 36 of 51284
# ...

# %%
with open('wtwt_extracted.json', 'w', encoding='utf-8') as f:
    json.dump(wtwt, f, indent=4)

# %%
with open('invalid.txt', 'w') as f:
    for item in invalid:
        f.write("%s\n" % item)
